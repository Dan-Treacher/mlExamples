# %% [markdown]
# # Using google news as a source
#
# Found library called pygooglenews that allows filtering by release date etc

# %%
from pygooglenews import GoogleNews

# %%
gn = GoogleNews(lang = 'en', country = 'US')
#business = gn.topic_headlines('BUSINESS', proxies=None, scraping_bee = None)

# %%
# Found 1 discrepancy 3 trials in pulling results from this command and what's on google news.
# Note that the from_ and to_ dates are YYYY-MM-DD
# helper converts arg1 from regular strings to expression interpreted by google ('what is helper' -> 'what%20is%20helper') etc

#test = gn.search('time', helper = True, from_ = '2017/3/2', to_ = '2018/4/15')['entries']
test2 = gn.search('microsoft', from_ = '2020/1/1', to_ = '2020/06/01')
print(len(test2['entries']))  # Looks like there's 100 returns max(?)
test2['entries']
# Out:
# 100
# [{'title': 'From Microsoft Teams to Fluid Framework—here’s what’s new and coming soon to Microsoft 365 - Microsoft',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': '',
#    'value': 'From Microsoft Teams to Fluid Framework—here’s what’s new and coming soon to Microsoft 365 - Microsoft'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://www.microsoft.com/en-us/microsoft-365/blog/2020/05/19/microsoft-teams-fluid-framework-new-microsoft-365/'}],
#   'link': 'https://www.microsoft.com/en-us/microsoft-365/blog/2020/05/19/microsoft-teams-fluid-framework-new-microsoft-365/',
#   'id': 'CBMicGh0dHBzOi8vd3d3Lm1pY3Jvc29mdC5jb20vZW4tdXMvbWljcm9zb2Z0LTM2NS9ibG9nLzIwMjAvMDUvMTkvbWljcm9zb2Z0LXRlYW1zLWZsdWlkLWZyYW1ld29yay1uZXctbWljcm9zb2Z0LTM2NS_SAXRodHRwczovL3d3dy5taWNyb3NvZnQuY29tL2VuLXVzL21pY3Jvc29mdC0zNjUvYmxvZy8yMDIwLzA1LzE5L21pY3Jvc29mdC10ZWFtcy1mbHVpZC1mcmFtZXdvcmstbmV3LW1pY3Jvc29mdC0zNjUvYW1wLw',
# ...

# %%
# fish all articles that have the word 'boeing' in the title that have been published within the last hour

s = gn.search('intitle:boeing', from_ = '2020/1/1', to_ = '2020/06/01')



for entry in s['entries']:
    print(entry['title'])
    print(entry['summary'])
    print(' ')
#print(s['entries'])
# Out:
# Boeing kills its $4.2 billion purchase of Embraer as coronavirus roils the aviation industry - Seattle Times
# ...

# %%
print(s['entries'][0].keys())

s['entries'][0]['summary'].split('target="_blank">')[1]
s['entries'][0]['sub_articles']

#import pandas as pd

#print(pd.to_datetime(s['entries'][0]['published']))
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'id', 'guidislink', 'published', 'published_parsed', 'summary', 'summary_detail', 'source', 'sub_articles'])
# [{'url': 'https://www.seattletimes.com/business/boeing-aerospace/boeing-kills-its-4-2-billion-purchase-of-embraer/',
#   'title': 'Boeing kills its $4.2 billion purchase of Embraer as coronavirus roils the aviation industry',
#   'publisher': 'Seattle Times'},
#  {'url': 'https://www.cnn.com/2020/04/25/business/boeing-embraer-termination/index.html',
#   'title': 'Boeing terminates $4.2 billion deal with Embraer',
#   'publisher': 'CNN'},
#  {'url': 'https://www.washingtonpost.com/business/2020/04/25/boeing-backs-out-embraer-merger/',
#   'title': 'Boeing backs out of Embraer merger',
#   'publisher': 'The Washington Post'},
#  {'url': 'https://www.wsj.com/articles/boeing-walks-away-from-embraer-deal-11587828846',
#   'title': 'Boeing Walks Away From Embraer Deal',
#   'publisher': 'The Wall Street Journal'},
# ...

# %% [markdown]
# # For a more social media angle, try and fish old tweets
#
# Social media stuff is better handled with vader nlp library than financial stuff

# %%
import GetOldTweets3 as got

text_query = 'USA Election 2020'
since_date = '2019-01-01'
until_date = '2019-10-31'
count = 2000

# Creation of query object
tweetCriteria = got.manager.TweetCriteria().setQuerySearch(text_query).setSince(since_date).setUntil(until_date).setMaxTweets(count)

# Creation of list that contains all tweets
tweets = got.manager.TweetManager.getTweets(tweetCriteria)

# Creating list of chosen tweet data
text_tweets = [[tweet.date, tweet.text] for tweet in tweets]

# %%
dir(tweets[0])

text_tweets[0][1]
# Out:
# 'Hearts were moving, and thousands of well wishers from all over the world and the USA. THEY are loved by millions During the 2020 election year, they alone will bring in millions of people at their events, and much happiness to the USA .'

# %% [markdown]
# Get tweets by username and bound dates and preserve emojis as unicode:

# %%
tweetCriteria = got.manager.TweetCriteria().setUsername("barackobama")\
                                           .setSince("2015-09-10")\
                                           .setUntil("2016-01-01")\
                                           .setMaxTweets(1)\
                                           .setEmoji("unicode")
tweet = got.manager.TweetManager.getTweets(tweetCriteria)[0]
print(tweet.text)
# Out:
# You don't want to miss this. Say you'll tune in for President Obama's final #SOTU: http://ofa.bo/y2

# %% [markdown]
# Get the last 10 top tweets by username:

# %%
tweetCriteria = got.manager.TweetCriteria().setUsername("barackobama")\
                                           .setTopTweets(True)\
                                           .setMaxTweets(10)
tweet = got.manager.TweetManager.getTweets(tweetCriteria)[0]
print(tweet.text)
# Out:
# I’m joining my friend @JoeBiden tomorrow to talk about everything that’s at stake in this election. I hope you’ll join us, too. This is a critical moment in our history––and all of us have to do our part to build this country into what we know it can be.
